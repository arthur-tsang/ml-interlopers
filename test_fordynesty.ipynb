# %% [markdown]
# # Test fordynesty
#
# *20 May 2024*

# %%
import numpy as np
import matplotlib.pyplot as plt

import pickle

# %%
with open('fordynesty/000_params.p', 'rb') as f:
    params = pickle.load(f)

# %%
params
# Out:
# {'z': [0.5],
#  'gamma': 2.2151893663724196,
#  'phi_lens': 0.32284066732476147,
#  'q_lens': 0.7724415914984484,
#  'center_lens_x': -0.030538080264438106,
#  'center_lens_y': 0.058357645226662425,
#  'shear1': -0.0124825577474615,
#  'shear2': 0.07835460015641596,
#  'lens_a3': 0.018546510420041174,
#  'lens_phi3': -0.24411951211368066,
#  'lens_a4': 0.01166900152330658,
#  'lens_phi4': 0.04538803381089562,
#  'source_phi': -2.695259936440876,
#  'source_center_x': 0.027217824437572924,
#  'source_center_y': 0.17023865531706445,
#  'mass_sheets': True,
#  'x': [-0.8],
#  'y': [0.5],
#  'mass_multiplier': array([0.34959455])}

# %%
r20_c60 = np.load('fordynesty/000_r20_c60.npy')

# %%
r20_c60.shape
# Out:
# (320, 320)

# %%
plt.imshow(r20_c60, 'turbo')

# %%
r20_none = np.load('fordynesty/000_r20_none.npy')

# %%
plt.imshow(r20_none, 'turbo')

# %%
plt.imshow(r20_c60 - r20_none, 'turbo')

# %%
r80_c15 = np.load('fordynesty/000_r80_c15.npy')
plt.imshow(r80_c15, 'turbo')

# %%
r80_c60 = np.load('fordynesty/000_r80_c60.npy')
plt.imshow(r80_c60, 'turbo')

# %%
r80_none= np.load('fordynesty/000_r80_none.npy')
plt.imshow(r80_none, 'turbo')

# %%
plt.imshow(r80_c60 - r80_none, 'turbo')
plt.colorbar()

# %%
plt.imshow(r80_c15 - r80_none, 'turbo')
plt.colorbar()

# %%
plt.imshow(r80_c60 - r80_c15, 'turbo')
plt.colorbar()
